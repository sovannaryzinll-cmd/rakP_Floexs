# %% [markdown]
# <a href="https://colab.research.google.com/github/sovannaryzinll-cmd/rakP_Floexs/blob/main/ADS_LESSONS_PRACTISE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
#work /21.11.2025/

# %%
# thusday 21st November 2025
import csv

SIZE = 50
hash_table = [None] * SIZE

def hash_code(key):
    return key % SIZE

def insert(key, value):
    index = hash_code(key)
    while hash_table[index] is not None:
        index = (index + 1) % SIZE
    hash_table[index] = (key, value)

def search(key):
    index = hash_code(key)
    while hash_table[index] is not None:
        if hash_table[index][0] == key:
            return hash_table[index]
        index = (index + 1) % SIZE
    return None

# Load CSV
with open("/content/students.csv") as f:
    reader = csv.DictReader(f)
    for row in reader:
        insert(int(row["StudentID"]), row["Name"])

# Test search
print(search(1003))
# Out:
# (1003, 'Ken Sreyna')
